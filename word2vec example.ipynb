# %%
import gensim
import gensim.downloader as api
from gensim.models import Word2Vec, KeyedVectors

# %%
w2v = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king = w2v['king']

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vec_king.shape
# Out:
# (300,)

# %%
vec_hopper = w2v["grasshopper"]

# %%
w2v.most_similar('grasshopper')
# Out:
# [('grasshoppers', 0.6111161708831787),
#  ('insect', 0.5721731185913086),
#  ('grackle', 0.561285674571991),
#  ('frog', 0.5571215748786926),
#  ('daddy_longlegs', 0.5418422222137451),
#  ('ant', 0.541286289691925),
#  ('caterpillars', 0.5388979911804199),
#  ('moth', 0.5354675650596619),
#  ('beetle', 0.5329505801200867),
#  ('caterpillar', 0.5305215716362)]

# %%
w2v.most_similar('enjoy')
# Out:
# [('enjoying', 0.7550566792488098),
#  ('enjoyed', 0.7027286887168884),
#  ('Enjoy', 0.65964674949646),
#  ('savor', 0.6369790434837341),
#  ('revel', 0.6139956712722778),
#  ('Enjoying', 0.5948812961578369),
#  ('appreciate', 0.5808993577957153),
#  ('enjoys', 0.5774140357971191),
#  ('bask', 0.5576348304748535),
#  ('dine_alfresco', 0.5526379346847534)]

# %%
w2v.similarity("grasshopper","cricket")
# Out:
# 0.20704599

# %%
w2v.similarity('happy','enjoy')
# Out:
# 0.3910905

# %%
vec = w2v['king'] - w2v['male'] + w2v['female']

# %%
w2v.most_similar([vec])
# Out:
# [('king', 0.8830681443214417),
#  ('queen', 0.6669611930847168),
#  ('kings', 0.6140398979187012),
#  ('monarch', 0.5949661135673523),
#  ('crown_prince', 0.5778266787528992),
#  ('sultan', 0.5558580160140991),
#  ('ruler', 0.5497739911079407),
#  ('prince', 0.5371752381324768),
#  ('Savory_aromas_wafted', 0.5148698687553406),
#  ('princess', 0.5138769149780273)]
